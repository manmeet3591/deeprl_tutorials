# %% [markdown]
# # Stable Baselines3 - Training, Saving and Loading
#
# Github Repo: [https://github.com/DLR-RM/stable-baselines3](https://github.com/DLR-RM/stable-baselines3)
#
#
# [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo) is a training framework for Reinforcement Learning (RL), using Stable Baselines3.
#
# It provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# Documentation is available online: [https://stable-baselines3.readthedocs.io/](https://stable-baselines3.readthedocs.io/)
#
# ## Install Dependencies and Stable Baselines Using Pip
#
#
# ```
# pip install stable-baselines3[extra]
# ```

# %%
# for autoformatting
# %load_ext jupyter_black

# %%
# !apt-get update && apt-get install swig cmake
# !pip install box2d-py
# !pip install "stable-baselines3[extra]>=2.0.0a4"
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://cli.github.com/packages stable/main amd64 Packages [345 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,205 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,851 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,633 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,546 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,287 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,205 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [69.3 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,965 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,598 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,411 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [36.9 kB]
# Fetched 38.2 MB in 5s (7,913 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 49 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 1s (823 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 121689 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting box2d-py
#   Downloading box2d-py-2.3.8.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.5/374.5 kB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.8-cp312-cp312-linux_x86_64.whl size=2381982 sha256=cccef2c21ea930466b21c54f3b2aceff434614ec1ddf5255324a97a1b9b3c58e
#   Stored in directory: /root/.cache/pip/wheels/d6/3c/ab/b6fd75459cadc56f4a4125d4cb387a708a59ca8589e4cc6b7d
# Successfully built box2d-py
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8
# Collecting stable-baselines3>=2.0.0a4 (from stable-baselines3[extra]>=2.0.0a4)
#   Downloading stable_baselines3-2.8.0a0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.2.2)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.0.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.9.0+cu126)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.10.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (4.12.0.88)
# Requirement already satisfied: pygame in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.19.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (0.11.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (11.3.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.0.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (25.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a4) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.0.3)
# Downloading stable_baselines3-2.8.0a0-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.4/187.4 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: stable-baselines3
# Successfully installed stable-baselines3-2.8.0a0

# %% [markdown]
# ## Import policy, RL agent, ...

# %%
import gymnasium as gym
import numpy as np

from stable_baselines3 import DQN

# %% [markdown]
# ## Create the Gym env and instantiate the agent
#
# For this example, we will use Lunar Lander environment.
#
# "Landing outside landing pad is possible. Fuel is infinite, so an agent can learn to fly and then land on its first attempt. Four discrete actions available: do nothing, fire left orientation engine, fire main engine, fire right orientation engine. "
#
# Lunar Lander environment: [https://gymnasium.farama.org/environments/box2d/lunar_lander/](https://gymnasium.farama.org/environments/box2d/lunar_lander/)
#
# ![Lunar Lander](https://cdn-images-1.medium.com/max/960/1*f4VZPKOI0PYNWiwt0la0Rg.gif)
#
#
# We chose the MlpPolicy because input of Lunar Lander is a feature vector, not images.
#
# The type of action to use (discrete/continuous) will be automatically deduced from the environment action space

# %%
model = DQN(
    "MlpPolicy",
    "LunarLander-v3",
    verbose=1,
    exploration_final_eps=0.1,
    target_update_interval=250,
)
# Out:
# Using cuda device
# Creating environment from the given name 'LunarLander-v3'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# We load a helper function to evaluate the agent:

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# Let's evaluate the un-trained agent, this should be a random agent.

# %%
# Separate env for evaluation
eval_env = gym.make("LunarLander-v3")

# Random Agent, before training
mean_reward, std_reward = evaluate_policy(
    model,
    eval_env,
    n_eval_episodes=10,
    deterministic=True,
)

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/evaluation.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward=-732.27 +/- 211.10942021711114

# %% [markdown]
# ## Train the agent and save it
#
# Warning: this may take a while

# %%
# Train the agent
model.learn(total_timesteps=int(1e5))
# Save the agent
model.save("dqn_lunar")
del model  # delete trained model to demonstrate loading
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -276     |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 438      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 366      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.11     |
# |    n_updates        | 66       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | -231     |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 668      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 868      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.24     |
# |    n_updates        | 191      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -203     |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 762      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1252     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38     |
# |    n_updates        | 287      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 811      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1596     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.27     |
# |    n_updates        | 373      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.2     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 845      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1943     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.06     |
# |    n_updates        | 460      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -209     |
# |    exploration_rate | 0.781    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 831      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2430     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.96     |
# |    n_updates        | 582      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.3     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.752    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 752      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2753     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.778    |
# |    n_updates        | 663      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -213     |
# |    exploration_rate | 0.709    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 678      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3228     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.68     |
# |    n_updates        | 781      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.673    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 634      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 3633     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.68     |
# |    n_updates        | 883      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 111      |
# |    ep_rew_mean      | -221     |
# |    exploration_rate | 0.602    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 663      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 4424     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38     |
# |    n_updates        | 1080     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 114      |
# |    ep_rew_mean      | -216     |
# |    exploration_rate | 0.549    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 681      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 5008     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.17     |
# |    n_updates        | 1226     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -209     |
# |    exploration_rate | 0.493    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 680      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 5638     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14     |
# |    n_updates        | 1384     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 128      |
# |    ep_rew_mean      | -208     |
# |    exploration_rate | 0.401    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 668      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 6655     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.817    |
# |    n_updates        | 1638     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 149      |
# |    ep_rew_mean      | -207     |
# |    exploration_rate | 0.247    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 647      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 8368     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.861    |
# |    n_updates        | 2066     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | -201     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 521      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 11598    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.832    |
# |    n_updates        | 2874     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 231      |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 484      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 14789    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.7      |
# |    n_updates        | 3672     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 264      |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 461      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 17967    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.21     |
# |    n_updates        | 4466     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 293      |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 444      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 21113    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.04     |
# |    n_updates        | 5253     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 310      |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 438      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 23558    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.862    |
# |    n_updates        | 5864     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 313      |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 436      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 25074    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.838    |
# |    n_updates        | 6243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 426      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 28232    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.69     |
# |    n_updates        | 7032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 337      |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 426      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 29663    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.891    |
# |    n_updates        | 7390     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 338      |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 426      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 31075    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.21     |
# |    n_updates        | 7743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 340      |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 427      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 32645    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.59     |
# |    n_updates        | 8136     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 350      |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 421      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 35006    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.835    |
# |    n_updates        | 8726     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 361      |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 421      |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 36445    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.785    |
# |    n_updates        | 9086     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 396      |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 413      |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 40445    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.572    |
# |    n_updates        | 10086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 432      |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 409      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 44445    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.808    |
# |    n_updates        | 11086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 468      |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 404      |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 48445    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.936    |
# |    n_updates        | 12086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 505      |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 402      |
# |    time_elapsed     | 130      |
# |    total_timesteps  | 52445    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.855    |
# |    n_updates        | 13086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 540      |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 406      |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 56445    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.17     |
# |    n_updates        | 14086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 577      |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 404      |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 60445    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.622    |
# |    n_updates        | 15086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 611      |
# |    ep_rew_mean      | -154     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 403      |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 64338    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14     |
# |    n_updates        | 16059    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 647      |
# |    ep_rew_mean      | -146     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 398      |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 68338    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.716    |
# |    n_updates        | 17059    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 679      |
# |    ep_rew_mean      | -140     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 397      |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 72338    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.817    |
# |    n_updates        | 18059    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 713      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 397      |
# |    time_elapsed     | 191      |
# |    total_timesteps  | 76338    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.744    |
# |    n_updates        | 19059    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 746      |
# |    ep_rew_mean      | -135     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 398      |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 80202    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.757    |
# |    n_updates        | 20025    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 775      |
# |    ep_rew_mean      | -129     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 396      |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 84202    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.495    |
# |    n_updates        | 21025    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 797      |
# |    ep_rew_mean      | -122     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 395      |
# |    time_elapsed     | 222      |
# |    total_timesteps  | 88072    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.545    |
# |    n_updates        | 21992    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 804      |
# |    ep_rew_mean      | -119     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 397      |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 92008    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.656    |
# |    n_updates        | 22976    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 810      |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 397      |
# |    time_elapsed     | 241      |
# |    total_timesteps  | 95823    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.658    |
# |    n_updates        | 23930    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 819      |
# |    ep_rew_mean      | -112     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 394      |
# |    time_elapsed     | 253      |
# |    total_timesteps  | 99823    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.599    |
# |    n_updates        | 24930    |
# ----------------------------------

# %% [markdown]
# ## Load the trained agent

# %%
model = DQN.load("dqn_lunar")

# %%
# Evaluate the trained agent
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=-37.93 +/- 21.97582688289185
